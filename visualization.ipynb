# %%
import os

import joblib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from metrics.visualization import visualization

# %matplotlib inline

# %%
path = "output/test"

ori_data = joblib.load(os.path.join(path, "train_data.jlb"))
new_data = joblib.load(os.path.join(path, "generated_data.jlb"))

# %%
visualization(ori_data, new_data, 'pca')

# %%
visualization(ori_data, new_data, 'tsne')
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 2000 samples in 0.305s...
# [t-SNE] Computed neighbors for 2000 samples in 0.500s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2000
# [t-SNE] Computed conditional probabilities for sample 2000 / 2000
# [t-SNE] Mean sigma: 0.000003
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 49.313019
# [t-SNE] KL divergence after 300 iterations: 0.407193
