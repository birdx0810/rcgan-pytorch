# %%
import os

import joblib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from metrics.visualization import visualization

# %matplotlib inline

# %%
path = "output/timegan_adam_250"

ori_data = joblib.load(os.path.join(path, "train_data.jlb"))
new_data = joblib.load(os.path.join(path, "generated_data.jlb"))

# %%
visualization(ori_data, new_data, 'pca')

# %%
visualization(ori_data, new_data, 'tsne')
# Out:
# [t-SNE] Computing 101 nearest neighbors...
# [t-SNE] Indexed 102 samples in 0.000s...
# [t-SNE] Computed neighbors for 102 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 102 / 102
# [t-SNE] Mean sigma: 0.000338
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 48.319736
# [t-SNE] KL divergence after 300 iterations: 0.112180
